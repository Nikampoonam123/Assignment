# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=(10,4)
plt.rcParams['figure.dpi']=300

# To perform Simple Linear Regression
import statsmodels.formula.api as smf

# To avoid warnings
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # delivery_time

# %%
#Read Data
df = pd.read_csv('D:\Data Science Assignments\Assignment 4 Simple LR\delivery_time.csv')
df
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 468.0 bytes

# %%
df[df.duplicated()] # No duplicates
# Out:
# Empty DataFrame
# Columns: [Delivery Time, Sorting Time]
# Index: []

# %%
df.isnull().sum() # No missing values
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
df.boxplot() # To check Outliers
# Out:
# <Axes: >

# %%
# Rename columns
df.rename(columns={'Delivery Time':'Delivery_Time','Sorting Time':'Sorting_Time'},inplace=True)

# %%
# To see realtion between two variables
sns.scatterplot(x=df['Delivery_Time'],y=df['Sorting_Time'])
# Out:
# <Axes: xlabel='Delivery_Time', ylabel='Sorting_Time'>

# %%
# Magnitude of relation between two variables
df.corr()
# Out:
#                Delivery_Time  Sorting_Time
# Delivery_Time       1.000000      0.825997
# Sorting_Time        0.825997      1.000000

# %%
sns.heatmap(df.corr(),annot=True) #Visualize the correlation
# Out:
# <Axes: >

# %%
# Model building
model = smf.ols('Delivery_Time ~ Sorting_Time',data=df).fit()
model

# %%
# Parameter such as slope and intercept
model.params
# Out:
# Intercept       6.582734
# Sorting_Time    1.649020
# dtype: float64

# %%
c,m=model.params

# %%
c,m
# Out:
# (6.582733971997052, 1.6490198968312457)

# %%
# Best fit line
plt.plot(df['Sorting_Time'],m*df['Sorting_Time']+c)

# %%
# Evaluation of model
model.rsquared, model.rsquared_adj
# Out:
# (0.6822714748417231, 0.6655489208860244)

# %%
#Test data
test = pd.DataFrame({
    'Sorting_Time' : [10,2,8,6,9]
})
test
# Out:
#    Sorting_Time
# 0            10
# 1             2
# 2             8
# 3             6
# 4             9

# %%
#Predictions
model.predict(test)
# Out:
# 0    23.072933
# 1     9.880774
# 2    19.774893
# 3    16.476853
# 4    21.423913
# dtype: float64

# %%
df
# Out:
#     Delivery_Time  Sorting_Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
plt.subplot(1,2,1)
sns.distplot(df['Delivery_Time'])

plt.subplot(1,2,2)
sns.distplot(df['Sorting_Time'])

plt.tight_layout()

# %%
df['Delivery_Time'].skew(),df['Sorting_Time'].skew()
# Out:
# (0.3523900822831107, 0.047115474210530174)

# %%
df['Log_Delivery_Time'] = np.log(df['Delivery_Time'])
df['Log_Sorting_Time'] = np.log(df['Sorting_Time'])
df
# Out:
#     Delivery_Time  Sorting_Time  Log_Delivery_Time  Log_Sorting_Time
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['Log_Delivery_Time'])

plt.subplot(1,2,2)
sns.distplot(df['Log_Sorting_Time'])

plt.tight_layout()

# %%
df['Log_Delivery_Time'].skew(),df['Log_Sorting_Time'].skew()
# Out:
# (-0.4512901148522999, -0.6052357185134765)

# %%
df['Sqrt_Delivery_Time'] = np.sqrt(df['Delivery_Time'])
df['Sqrt_Sorting_Time'] = np.sqrt(df['Sorting_Time'])
df
# Out:
#     Delivery_Time  Sorting_Time  Log_Delivery_Time  Log_Sorting_Time  \
# 0           21.00            10           3.044522          2.302585
# 1           13.50             4           2.602690          1.386294
# 2           19.75             6           2.983153          1.791759
# 3           24.00             9           3.178054          2.197225
# 4           29.00            10           3.367296          2.302585
# 5           15.35             6           2.731115          1.791759
# 6           19.00             7           2.944439          1.945910
# 7            9.50             3           2.251292          1.098612
# 8           17.90            10           2.884801          2.302585
# 9           18.75             9           2.931194          2.197225
# 10          19.83             8           2.987196          2.079442
# 11          10.75             4           2.374906          1.386294
# 12          16.68             7           2.814210          1.945910
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['Sqrt_Delivery_Time'])

plt.subplot(1,2,2)
sns.distplot(df['Sqrt_Sorting_Time'])

plt.tight_layout()

# %%
df['Sqrt_Delivery_Time'].skew(),df['Sqrt_Sorting_Time'].skew()
# Out:
# (-0.0618105135865213, -0.25981634723613994)

# %% [markdown]
# # Salary_data

# %%
#Read the data
df = pd.read_csv('D:\Data Science Assignments\Assignment 4 Simple LR\Salary_data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.dtypes #Data types
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
df[df.duplicated()] #No duplicates
# Out:
# Empty DataFrame
# Columns: [YearsExperience, Salary]
# Index: []

# %%
df.isnull().sum() #No missing values
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.boxplot() # To check outliers
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience'>

# %%
sns.scatterplot(x=df['YearsExperience'],y=df['Salary']) #Visualize relation
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
df.corr() # How much variables are related to each other
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
sns.heatmap(df.corr(),annot=True) # Visualize relation
# Out:
# <Axes: >

# %%
# Model building
model = smf.ols('Salary~YearsExperience',data=df).fit()
model

# %%
#Parameter
model.params
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
c,m = model.params
c,m
# Out:
# (25792.20019866871, 9449.962321455074)

# %%
# Best fit line
plt.plot(df['YearsExperience'],m*df['YearsExperience'])

# %%
# Evaluation of model
model.rsquared,model.rsquared_adj
# Out:
# (0.9569566641435086, 0.9554194021486339)

# %%
# Test Data
test = pd.DataFrame({
    'YearsExperience' : [1,15.2,8,6.4,7.9]
})
test
# Out:
#    YearsExperience
# 0              1.0
# 1             15.2
# 2              8.0
# 3              6.4
# 4              7.9

# %%
# Prediction
model.predict(test)
# Out:
# 0     35242.162520
# 1    169431.627485
# 2    101391.898770
# 3     86271.959056
# 4    100446.902538
# dtype: float64

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.subplot(1,2,1)
sns.distplot(df['YearsExperience'])

plt.subplot(1,2,2)
sns.distplot(df['Salary'])

plt.tight_layout()

# %%
df['YearsExperience'].skew(),df['Salary'].skew()
# Out:
# (0.37956024064804106, 0.35411967922959153)

# %%
df['Log_YearsExperience'] = np.log(df['YearsExperience'])
df['Log_Salary'] = np.log(df['Salary'])
df
# Out:
#     YearsExperience    Salary  Log_YearsExperience  Log_Salary
# 0               1.1   39343.0             0.095310   10.580073
# 1               1.3   46205.0             0.262364   10.740843
# 2               1.5   37731.0             0.405465   10.538237
# 3               2.0   43525.0             0.693147   10.681091
# 4               2.2   39891.0             0.788457   10.593906
# 5               2.9   56642.0             1.064711   10.944506
# 6               3.0   60150.0             1.098612   11.004597
# 7               3.2   54445.0             1.163151   10.904946
# 8               3.2   64445.0             1.163151   11.073567
# 9               3.7   57189.0             1.308333   10.954117
# 10              3.9   63218.0             1.360977   11.054344
# 11              4.0   55794.0             1.386294   10.929422
# 12              4.0   56957.0             1.386294   10.950052
# 13              4.1   57081.0             1.410987   10.952227
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['Log_YearsExperience'])

plt.subplot(1,2,2)
sns.distplot(df['Log_Salary'])

plt.tight_layout()

# %%
df['Log_YearsExperience'].skew(),df['Log_Salary'].skew()
# Out:
# (-0.6005648582626513, -0.044126086756988495)

# %%
df['sqrt_YearsExperience'] = np.sqrt(df['YearsExperience'])
df['sqrt_Salary'] = np.sqrt(df['Salary'])
df
# Out:
#     YearsExperience    Salary  Log_YearsExperience  Log_Salary  \
# 0               1.1   39343.0             0.095310   10.580073
# 1               1.3   46205.0             0.262364   10.740843
# 2               1.5   37731.0             0.405465   10.538237
# 3               2.0   43525.0             0.693147   10.681091
# 4               2.2   39891.0             0.788457   10.593906
# 5               2.9   56642.0             1.064711   10.944506
# 6               3.0   60150.0             1.098612   11.004597
# 7               3.2   54445.0             1.163151   10.904946
# 8               3.2   64445.0             1.163151   11.073567
# 9               3.7   57189.0             1.308333   10.954117
# 10              3.9   63218.0             1.360977   11.054344
# 11              4.0   55794.0             1.386294   10.929422
# 12              4.0   56957.0             1.386294   10.950052
# 13              4.1   57081.0             1.410987   10.952227
# ...

# %%
plt.subplot(1,2,1)
sns.distplot(df['sqrt_YearsExperience'])

plt.subplot(1,2,2)
sns.distplot(df['sqrt_Salary'])

plt.tight_layout()

# %%
df['sqrt_YearsExperience'].skew(),df['sqrt_Salary'].skew()
# Out:
# (-0.04919608394250605, 0.16904336802767353)
